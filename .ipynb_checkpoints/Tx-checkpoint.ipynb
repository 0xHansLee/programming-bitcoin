# %%
from helper import (
    hash256,
    int_to_little_endian,
    little_endian_to_int,
    read_varint,
    encode_varint,
    SIGHASH_ALL,
)
from io import BytesIO
import json
import requests
from script import script

# Transaction class (version, inputs, outputs, locktime)
class Tx:
    
    def __init__(self, version, tx_ins, tx_outs, locktime, testnet=False):
        self.version = version
        self.tx_ins = tx_ins
        self.tx_outs = tx_outs
        self.locktime = locktime
        self.testnet = testnet
        
    def __repr__(self):
        tx_ins = ''
        for tx_in in self.tx_ins:
            tx_ins += tx_in.__repr__() + '\n'
            
        tx_outs = ''
        for tx_out in self.tx_outs:
            tx_outs += tx_out.__repr__() + '\n'
        
        return f'tx : {self.id()}\nversion : {self.version}\ntx inputs : \n{tx_ins}tx outputs : \n{tx_outs}locktime : self.locktime'
    
    def id(self):
        '''Transaction hash in hexadecimal'''
        return self.hash().hex()
    
    def hash(self):
        '''Binary hash of the legacy serialization'''
        return hash256(self.serialize())[::-1]
    
    @classmethod
    def parse(cls, s, testnet=False):
        version = little_endian_to_int(s.read(4))
        
        n_inputs = read_varint(s)
        inputs = []
        for _ in range(n_inputs):
            inputs.append(TxInput.parse(s))
        
        n_outputs = read_varint(s)
        outputs = []
        for _ in range(n_outputs):
            outputs.append(TxOutput.parse(s))
            
        locktime = little_endian_to_int(s.read(4))
        return cls(version, inputs, outputs, locktime, testnet=testnet)
        
    def serialize(self):
        '''Returns the byte serialize of the Tx'''
        result = int_to_little_endian(self.version, 4)
        result += encode_varint(len(self.tx_ins))
        for tx_in in self.tx_ins:
            result += tx_in.serialize()
        result += encode_varint(len(self.tx_outs))
        for tx_out in self.tx_outs:
            result += tx_out.serialize()
        result += int_to_little_endian(self.locktime, 4)
        return result
    
    def fee(self, testnet=False):
        '''Calculate fee'''
        total_in_value = 0
        for tx_in in self.tx_ins:
            total_in_value += tx_in.value(testnet=False)
            
        total_out_value = 0
        for tx_out in self.tx_outs:
            total_out_value += tx_out.amount
            
        return total_in_value - total_out_value
    
    # make sig_hash (SIGHASH_ALL)
    def sig_hash(self, input_index):
        result = int_to_little_endian(self.version, 4)
        result += encode_varint(len(self.tx_ins))
        for idx, tx_in in enumerate(tx_ins):
            if idx == input_index:
                tx_in.script_sig = tx_in.get_script_lock(self.testnet)
            else:
                tx_in.script_sig = None
            result += TxInput(tx_in.prev_tx, tx_in.prev_index, tx_in.script_sig, tx_in.sequence).serialize()
        result += encode_varint(len(self.tx_outs))
        for tx_out in enumerate(tx_outs):
            result += tx_out.serialize()
        result += int_to_little_endial(self.locktime, 4)
        result += int_to_little_endial(SIGHASH_ALL, 4)
        h256 = hash256(result)
        return int.from_bytes(h256, 'big')
    
    def verify_input(self, input_index):
        tx_in = self.tx_ins[input_index]
        script_lock = tx_in.get_script_lock(testnet=False)
        z = self.sig_hash(input_index)
        combined_script = tx_in.script_sig + script_lock
        return combined_script.evalutate(z)
        
    def verify_Tx(self):
        '''
        Verify the Tx
        1. fee >= 0
        2. valid UTXO input
        3. valid Signature
        '''
        if self.fee() < 0:
            return False
        for i in range(len(self.tx_ins)):
            if not self.verify_input(i):
                return False
        return True
        
    
        
# Transaction input class        
class TxInput:
    
    def __init__(self, prev_tx, prev_index, script_sig=None, sequence=0xffffffff):
        self.prev_tx = prev_tx
        self.prev_index = prev_index
        if script_sig is None:
            self.script_sig = script()
        else:
            self.script_sig = script_sig
        self.sequence = sequence
        
    def __repr__(self):
        return f'{self.prev_tx.hex()}:{self.prev_index}'
        
    @classmethod
    def parse(cls, s):
#         prev_tx = little_endian_to_int(s.read(32)) # need to check
        prev_tx = s.read(32)[::-1] # in bytes?
        prev_index = little_endian_to_int(s.read(4))
#         len_script_sig = read_varint(s)
#         script_sig = little_endian_to_int(s.read(len_script_sig))
        script_sig = script.parse(s)
        sequence = little_endian_to_int(s.read(4))
        return cls(prev_tx, prev_index, script_sig, sequence)
    
    def serialize(self):
        '''Returns the byte of serialization of Tx input'''
        result = self.prev_tx[::-1]
        result += int_to_little_endian(self.prev_index, 4)
        result += self.script_sig.serialize()
        result += int_to_little_endian(self.sequence, 4)
        return result
    
    def fetch_tx(self, testnet=False):
        return TxFetcher.fetch(self.prev_tx.hex(), testnet)
    
    def value(self, testnet=False):
        tx = self.fetch_tx(testnet=testnet)
        return tx.tx_outs[self.prev_index].amount
    
    def get_script_lock(self, testnet=False):
        tx = self.fetch_tx(testnet=testnet)
        return tx.tx_outs[self.prev_index].script_lock
    
    
# Transacrion output class
class TxOutput:
    
    def __init__(self, amount, script_lock):
        self.amount = amount
        self.script_lock = script_lock
        
    def __repr__(self):
        return f'{self.amount}(in satosi):{self.script_lock}'
    
    @classmethod
    def parse(cls, s):
        amount = little_endian_to_int(s.read(8))
        script_lock = script.parse(s)
        return cls(amount, script_lock)
    
    def serialize(self):
        '''Returns the byte serialization of the Tx output'''
        result = int_to_little_endian(self.amount, 8)
        result += self.script_lock.serialize() # script class?
        return result
    
# Tx Fetcher class
class TxFetcher:
    
    cache = {}
    
    @classmethod
    def get_url(cls, testnet=False):
        if testnet:
            return 'http://testnet.programmingbitcoin.com'
        else:
            return 'http://mainnet.programmingbitcoin.com'
        
    @classmethod
    def fetch(cls, tx_id, testnet=False, fresh=False):
        if fresh or (tx_id not in cls.cache): # need to fetch
            url = f'{cls.get_url(testnet)}/tx/{tx_id}.hex'
            response = requests.get(url)
            try:
                raw = bytes.fromhex(response.text.strip())
            except ValueError:
                raise ValueError(f'unexpected response :{response.text}')
            if raw[4] == 0: # raw[4] == 0 은 어떤 케이스?
                raw = raw[:4] + raw[6:]
                tx = Tx.parse(BytesIO(raw), testnet=testnet)
                tx.locktime = little_endian_to_int(raw[-4:])
            else:
                tx = Tx.parse(BytesIO(raw), testnet=testnet)
            if tx.id() != tx_id:
                raise ValueError(f'not the same id: {tx.id()} vs {tx_id}')
                
            cls.cache[tx_id] = tx
        cls.cache[tx_id].testnet = testnet
        return cls.cache[tx_id]
# Out:
# cMahea7zqjxrtgAbB7LSGbcQUr1uX1ojuat9jZodMN8rFTv2sfUK
# 91avARGdfge8E4tZfYLoxeJ5sGBdNJQH4kvjpWAxgzczjbCwxic
# KwDiBf89QgGbjEhKnhXJuH7LrciVrZi3qYjgiuQJv1h8Ytr2S53a
# b'd'
# 206966894896
# 1
# b'\x81'
# -1

# %%
from helper import decode_base58, SIGHASH_ALL
from script import get_p2pkh_script_lock, script
from Tx import TxInput, TxOutput, Tx
prev_tx = bytes.fromhex('0d6fe5213c0b3291f208cba8bfb59b7476dffacc4e5cb66f6eb20a080843a299')
prev_index = 13
# tx_in = TxInput(prev_tx, prev_index)
tx_in = TxInput(prev_tx, prev_index)
tx_outs = []
change_amount = int(0.33*100000000)
change_h160 = decode_base58('mzx5YhAH9kNHtcN481u6WkjeHjYtVeKVh2')
change_script = get_p2pkh_script_lock(change_h160)
change_output = TxOutput(amount=change_amount, script_lock=change_script)
target_amount = int(0.1*100000000)
target_h160 = decode_base58('mnrVtF8DWjMu839VW3rBfgYaAfKk8983Xf')
target_script = get_p2pkh_script_lock(target_h160)
target_output = TxOutput(amount=target_amount, script_lock=target_script)
tx_obj = Tx(1, [tx_in], [change_output, target_output], 0, True)
print(tx_obj)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-c0a430cf2c45> in <module>
#       1 from helper import decode_base58, SIGHASH_ALL
#       2 from script import get_p2pkh_script_lock, script
# ----> 3 from Tx import TxInput, TxOutput, Tx
#       4 prev_tx = bytes.fromhex('0d6fe5213c0b3291f208cba8bfb59b7476dffacc4e5cb66f6eb20a080843a299')
#       5 prev_index = 13
#
# ~/ProgrammingBTC/MyBitcoinProgramming/Tx.py in <module>
#     252 target_output = TxOutput(amount=target_amount, script_lock=target_script)
#     253 tx_obj = Tx(1, [tx_in], [change_output, target_output], 0, True)
# --> 254 print(tx_obj)
#     255
#     256
#
# ~/ProgrammingBTC/MyBitcoinProgramming/Tx.py in __repr__(self)
#      37             tx_outs += tx_out.__repr__() + '\n'
#      38
# ---> 39         return f'tx : {self.id()}\nversion : {self.version}\ntx inputs : \n{tx_ins}tx outputs : \n{tx_outs}locktime : self.locktime'
#      40
#      41     def id(self):
#
# ~/ProgrammingBTC/MyBitcoinProgramming/Tx.py in id(self)
#      41     def id(self):
#      42         '''Transaction hash in hexadecimal'''
# ---> 43         return self.hash().hex()
#      44
#      45     def hash(self):
#
# ~/ProgrammingBTC/MyBitcoinProgramming/Tx.py in hash(self)
#      45     def hash(self):
#      46         '''Binary hash of the legacy serialization'''
# ---> 47         return hash256(self.serialize())[::-1]
#      48
#      49     @classmethod
#
# ~/ProgrammingBTC/MyBitcoinProgramming/Tx.py in serialize(self)
#      69         result += encode_varint(len(self.tx_ins))
#      70         for tx_in in self.tx_ins:
# ---> 71             result += tx_in.serialize()
#      72         result += encode_varint(len(self.tx_outs))
#      73         for tx_out in self.tx_outs:
#
# ~/ProgrammingBTC/MyBitcoinProgramming/Tx.py in serialize(self)
#     159         result = self.prev_tx[::-1]
#     160         result += int_to_little_endian(self.prev_index, 4)
# --> 161         result += self.script_sig.serialize()
#     162         result += int_to_little_endian(self.sequence, 4)
#     163         return result
#
# ~/ProgrammingBTC/MyBitcoinProgramming/script.py in serialize(self)
#     133
#     134     def serialize(self):
# --> 135         raw_serialized = self.raw_serialize()
#     136         len_script = len(raw_serialized)
#     137         return encode_varint(len_script) + raw_serialized
#
# ~/ProgrammingBTC/MyBitcoinProgramming/script.py in raw_serialize(self)
#     109         result = b''
#     110         # cmd should be consist of command (int) and element (byte)
# --> 111         for cmd in cmds:
#     112             # op_command if its type is int
#     113             if type(cmd) == int:
#
# NameError: name 'cmds' is not defined
